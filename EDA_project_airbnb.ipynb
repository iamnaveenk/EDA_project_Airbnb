# %% [markdown]
# <a href="https://colab.research.google.com/github/naveenkumar1805/EDA_project_Airbnb/blob/main/EDA_project_airbnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **What is AIRBNB?**
# The company has come a long way since 2007, when its co-founders first came up with the idea to invite paying guests to sleep on an air mattress in their living room.

# %% [markdown]
# **Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present a more unique, personalized way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analyzed and used for security, business decisions, understanding of customers' and providers' (hosts) behavior and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more.
# This dataset has around 49,000 observations in it with 16 columns and it is a mix between categorical and numeric values.**

# %%
# mounting drive 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#imprt pandas package
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %shell  %store  %sx  %system  %tb  %tensorflow_version  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
#upload data 
file_path='/content/drive/MyDrive/AirbnbNYC.csv'
df=pd.read_csv(file_path)

# %% [markdown]
# **1.UNDERSTANDING DATA**

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.describe().T
# Out:
#                                   count          mean           std  \
# id                              48895.0  1.901714e+07  1.098311e+07
# host_id                         48895.0  6.762001e+07  7.861097e+07
# latitude                        48895.0  4.072895e+01  5.453008e-02
# longitude                       48895.0 -7.395217e+01  4.615674e-02
# price                           48895.0  1.527207e+02  2.401542e+02
# minimum_nights                  48895.0  7.029962e+00  2.051055e+01
# number_of_reviews               48895.0  2.327447e+01  4.455058e+01
# reviews_per_month               38843.0  1.373221e+00  1.680442e+00
# calculated_host_listings_count  48895.0  7.143982e+00  3.295252e+01
# availability_365                48895.0  1.127813e+02  1.316223e+02
#
#                                        min           25%           50%  \
# id                              2539.00000  9.471945e+06  1.967728e+07
# host_id                         2438.00000  7.822033e+06  3.079382e+07
# ...

# %%
# finding unique value for all features
df.nunique()
# Out:
# id                                48895
# name                              47896
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %%
#finding how many room type(unique room ) in list 
list(df['room_type'].unique())
# Out:
# ['Private room', 'Entire home/apt', 'Shared room']

# %%
# finding how many Unique neighbourhood_group 
df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
#finding  number of times neighbourhood_group created  
df['neighbourhood_group'].value_counts()
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
# finding how many room type in index formate
df['room_type'].value_counts().index
# Out:
# Index(['Entire home/apt', 'Private room', 'Shared room'], dtype='object')

# %%
#findinhg number of times different roomtypes choosed
df['room_type'].value_counts()
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
#finding which neighbourhood created how many times 
df['neighbourhood'].value_counts().head(20)
# Out:
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
# Hell's Kitchen        1958
# East Village          1853
# Upper East Side       1798
# Crown Heights         1564
# Midtown               1545
# East Harlem           1117
# Greenpoint            1115
# Chelsea               1113
# Lower East Side        911
# Astoria                900
# Washington Heights     899
# West Village           768
# Financial District     744
# Flatbush               621
# Clinton Hill           572
# Name: neighbourhood, dtype: int64

# %%
#finding null values
df. isnull()
# Out:
#           id   name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 0      False  False    False      False                False          False
# 1      False  False    False      False                False          False
# 2      False  False    False      False                False          False
# 3      False  False    False      False                False          False
# 4      False  False    False      False                False          False
# ...      ...    ...      ...        ...                  ...            ...
# 48890  False  False    False      False                False          False
# 48891  False  False    False      False                False          False
# 48892  False  False    False      False                False          False
# 48893  False  False    False      False                False          False
# 48894  False  False    False      False                False          False
#
# ...

# %%
# finding missing values in particular column-show particular column
[features for features in df.columns if  df[features].isnull().sum()>0]
# Out:
# ['name', 'host_name', 'last_review', 'reviews_per_month']

# %%
#finding how many null values in paryicular column
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# fill null value in name and host_name beacuse on 16 and 21 respectively

df['name'].fillna(0,inplace=True)
df['host_name'].fillna('none',inplace=True)

# %%
#df.dropna(inplace=True)     # we can use also filna()

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
data=df.drop(['latitude','longitude'],axis=1)

# %%
#df.dropna(inplace=True)     # we can use also filna()

# %%
data1=df.drop(['latitude','longitude','last_review','reviews_per_month'],axis=1)

# %%
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
data1.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
data1.shape
# Out:
# (48895, 12)

# %%
data.shape
# Out:
# (48895, 14)

# %% [markdown]
# Data Analysis
# 1. find missing values
# 2. explore about numerical variables
# 3. explore about categorical variables
# 4. finding relationship between features

# %% [markdown]
# **1.What can we learn about different hosts and areas?**

# %%
host_areas= data1.groupby(['host_name','neighbourhood_group'])['calculated_host_listings_count'].count().reset_index()

# %%
host_areas.head(5)
# Out:
#                   host_name neighbourhood_group  \
# 0                    #NAME?              Queens
# 1                      'Cil              Queens
# 2           (Ari) HENRY LEE           Manhattan
# 3  (Email hidden by Airbnb)            Brooklyn
# 4  (Email hidden by Airbnb)           Manhattan
#
#    calculated_host_listings_count
# 0                               1
# 1                               1
# 2                               1
# 3                               2
# 4                               4

# %%
host_areas.sort_values("calculated_host_listings_count",ascending=False).head()
# Out:
#           host_name neighbourhood_group  calculated_host_listings_count
# 13217  Sonder (NYC)           Manhattan                             327
# 1834     Blueground           Manhattan                             230
# 9742        Michael           Manhattan                             212
# 3250          David           Manhattan                             202
# 9741        Michael            Brooklyn                             159

# %%
x=host_areas['neighbourhood_group']
y=host_areas['calculated_host_listings_count']

fig=plt.figure(figsize=(10,5))

plt.bar(x,y,color='blue',width=0.5)
plt.xlabel("neighbourhood_group")
plt.ylabel("calculated_host_listings_count")
plt.title("neighbourhood_group vs calculated_host_listings_count")
plt.show()

# %% [markdown]
# **Observation:**
# As we can see host Sounder(NYC) is most potential  host name followed by Blueground, Michael , David and they all are choose Manhattan .
# so we can say that Manhattan is mostly preffered neighourhood_group by host.

# %%
host_roomtype= data.groupby(['host_name','room_type','neighbourhood_group'])['calculated_host_listings_count'].count().reset_index()

# %%
host_roomtype.sort_values('calculated_host_listings_count',ascending=False).head(5)
# Out:
#           host_name        room_type neighbourhood_group  \
# 16549  Sonder (NYC)  Entire home/apt           Manhattan
# 2295     Blueground  Entire home/apt           Manhattan
# 12296       Michael  Entire home/apt           Manhattan
# 9189           Kara  Entire home/apt           Manhattan
# 4126          David  Entire home/apt           Manhattan
#
#        calculated_host_listings_count
# 16549                             319
# 2295                              230
# 12296                             143
# 9189                              129
# 4126                              117

# %%
x=host_roomtype['room_type']
y=host_roomtype['calculated_host_listings_count']

fig=plt.figure(figsize=(15,7))

plt.bar(x,y,color='blue',width=0.5)
plt.xlabel("room_type")
plt.ylabel("calculated_host_listings_count")
plt.title("room_type vs calculated_host_listings_count")
plt.show()

# %% [markdown]
# **Observation** AS we can see Entire home/apt is mostly prefered by hosts with respect to manhattan neighbourhood_group.

# %% [markdown]
# **2.What can we learn from predictions? (ex: locations, prices, reviews, etc)**

# %%
data1.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
reviews_prediction1=data1.groupby(['room_type','neighbourhood_group','neighbourhood','price','minimum_nights'])['number_of_reviews'].count().reset_index()

reviews_prediction1.sort_values('number_of_reviews', axis=0, ascending=False).head()
# Out:
#           room_type neighbourhood_group       neighbourhood  price  \
# 16880  Private room            Brooklyn            Bushwick     50
# 23161  Private room           Manhattan    Theater District    100
# 19681  Private room            Brooklyn        Williamsburg     60
# 16198  Private room            Brooklyn  Bedford-Stuyvesant     50
# 16234  Private room            Brooklyn  Bedford-Stuyvesant     55
#
#        minimum_nights  number_of_reviews
# 16880               1                 54
# 23161               1                 53
# 19681               2                 51
# 16198               1                 48
# 16234               1                 45

# %%
x=reviews_prediction1['price']
y=reviews_prediction1['number_of_reviews']
fig = plt.figure(figsize = (15, 7.5))
plt.scatter(x, y)

plt.xlabel("price")
plt.ylabel("number_of_reviews")
plt.title("price Vs Number of reviews")
plt.show()

# %%
x=reviews_prediction1['minimum_nights']
y=reviews_prediction1['price']
fig = plt.figure(figsize = (10, 5))
plt.scatter(x, y)

plt.xlabel("minimum_nights")
plt.ylabel("price")
plt.title("price Vs minimum_nights")
plt.show()

# %% [markdown]
# **Obervation**:As we can see from above where price is less maximum people are spent maximum nights and where price is less that room type is got maximum reviews.

# %%
reviews_prediction2=data.groupby(['room_type','neighbourhood_group','neighbourhood','number_of_reviews','minimum_nights'])['price'].mean().reset_index()

reviews_prediction2.sort_values('price', axis=0, ascending=False).head()
# Out:
#              room_type neighbourhood_group    neighbourhood  \
# 20830     Private room              Queens          Astoria
# 5851   Entire home/apt           Manhattan      East Harlem
# 19135     Private room           Manhattan  Lower East Side
# 9315   Entire home/apt           Manhattan          Tribeca
# 9958   Entire home/apt           Manhattan  Upper West Side
#
#        number_of_reviews  minimum_nights    price
# 20830                  2             100  10000.0
# 5851                   1               5   9999.0
# 19135                  6              99   9999.0
# 9315                   0             180   6500.0
# 9958                  17              14   6000.0

# %%
reviews_prediction3=data.groupby(['room_type','neighbourhood_group','neighbourhood','number_of_reviews','price'])['minimum_nights'].count().reset_index()

reviews_prediction3.sort_values('minimum_nights', axis=0, ascending=False).head()
# Out:
#              room_type neighbourhood_group     neighbourhood  \
# 21959     Private room            Brooklyn          Bushwick
# 25927     Private room            Brooklyn      Williamsburg
# 22018     Private room            Brooklyn          Bushwick
# 6748   Entire home/apt            Brooklyn      Williamsburg
# 31464     Private room           Manhattan  Theater District
#
#        number_of_reviews  price  minimum_nights
# 21959                  0     50              52
# 25927                  0     60              40
# 22018                  1     50              35
# 6748                   0    200              34
# 31464                  0    100              33

# %%
price_prediction=data1.groupby(['neighbourhood_group','room_type'])['price'].mean().unstack()
price_prediction.head()
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                     127.506596     66.788344    59.800000
# Brooklyn                  178.327545     76.500099    50.527845
# Manhattan                 249.239109    116.776622    88.977083
# Queens                    147.050573     71.762456    69.020202
# Staten Island             173.846591     62.292553    57.444444

# %% [markdown]
# **3.Which hosts are the busiest and why?**

# %%
host_busiest=data1.groupby(['host_name','number_of_reviews'])['minimum_nights'].count().reset_index()
host_busiest.sort_values('minimum_nights',axis=0,ascending=False).head(10)
# Out:
#           host_name  number_of_reviews  minimum_nights
# 4056     Blueground                  0             204
# 28406  Sonder (NYC)                  0             120
# 7283          David                  0              94
# 16138          Kara                  0              84
# 21453       Michael                  0              82
# 28401        Sonder                  0              67
# 24835       Pranjal                  0              64
# 6941         Daniel                  0              56
# 16628        Kazuya                  0              52
# 16771           Ken                  0              52

# %%
host_busiest=data1.groupby(['host_name'])['number_of_reviews'].max().reset_index()
host_busiest.sort_values('number_of_reviews',axis=0,ascending=False).head(10)
# Out:
#       host_name  number_of_reviews
# 2652       Dona                629
# 4931         Jj                607
# 6981       Maya                543
# 1673      Carol                540
# 2290   Danielle                510
# 936         Asa                488
# 10830     Wanda                480
# 6153      Linda                474
# 2273       Dani                467
# 661      Angela                466

# %% [markdown]
# **Busiest hosts are:**
#  1.Dona
#  2.Ji
#  3.Maya
#  4.Carol
#   5.Danielle
#
# Because these hosts listed room type as Entire home and Private room which is preferred by most number of people. as they give maximum reviews

# %%
host_busiest=data1.groupby(['host_name','room_type','neighbourhood_group'])['minimum_nights'].count().reset_index()
host_busiest.sort_values('minimum_nights',axis=0,ascending=False).head(10)
# Out:
#             host_name        room_type neighbourhood_group  minimum_nights
# 16549    Sonder (NYC)  Entire home/apt           Manhattan             319
# 2295       Blueground  Entire home/apt           Manhattan             230
# 12296         Michael  Entire home/apt           Manhattan             143
# 9189             Kara  Entire home/apt           Manhattan             129
# 4126            David  Entire home/apt           Manhattan             117
# 12436            Mike  Entire home/apt           Manhattan             109
# 542              Alex  Entire home/apt           Manhattan              98
# 16548          Sonder  Entire home/apt           Manhattan              96
# 8226   Jeremy & Laura  Entire home/apt           Manhattan              95
# 9548              Ken  Entire home/apt           Manhattan              95

# %% [markdown]
# **Busiest room type and neighbourhood group are:**
# Most Busiest room_type is Entire Home/apt and neighbourhood group is Manhattan because people are more stay at there.

# %% [markdown]
# **4. Is there any noticeable difference of traffic among different areas and what could be the reason for it?**

# %%
traffic_areas2= data.groupby(['room_type','neighbourhood_group'])['minimum_nights'].count().reset_index()
traffic_areas2.sort_values('minimum_nights',axis=0,ascending=False).head()
# Out:
#          room_type neighbourhood_group  minimum_nights
# 2  Entire home/apt           Manhattan           13199
# 6     Private room            Brooklyn           10132
# 1  Entire home/apt            Brooklyn            9559
# 7     Private room           Manhattan            7982
# 8     Private room              Queens            3372

# %%
traffic_areas3= data.groupby(['room_type','neighbourhood_group'])['minimum_nights'].mean().reset_index()
traffic_areas3.sort_values('minimum_nights',axis=0,ascending=False).head()
# Out:
#           room_type neighbourhood_group  minimum_nights
# 2   Entire home/apt           Manhattan       10.539283
# 11      Shared room            Brooklyn        7.753027
# 12      Shared room           Manhattan        6.766667
# 1   Entire home/apt            Brooklyn        6.531332
# 4   Entire home/apt       Staten Island        6.238636

# %%
traffic_areas3= data.groupby(['room_type','neighbourhood_group'])['price'].mean().reset_index()
traffic_areas3.sort_values('price',axis=0,ascending=False).head(25)
# Out:
#           room_type neighbourhood_group       price
# 2   Entire home/apt           Manhattan  249.239109
# 1   Entire home/apt            Brooklyn  178.327545
# 4   Entire home/apt       Staten Island  173.846591
# 3   Entire home/apt              Queens  147.050573
# 0   Entire home/apt               Bronx  127.506596
# 7      Private room           Manhattan  116.776622
# 12      Shared room           Manhattan   88.977083
# 6      Private room            Brooklyn   76.500099
# 8      Private room              Queens   71.762456
# 13      Shared room              Queens   69.020202
# 5      Private room               Bronx   66.788344
# 9      Private room       Staten Island   62.292553
# 10      Shared room               Bronx   59.800000
# 14      Shared room       Staten Island   57.444444
# 11      Shared room            Brooklyn   50.527845

# %%
#creating the bar plot
x=traffic_areas2['room_type']
y=traffic_areas2['minimum_nights']

plt.bar(x,y,color='blue',width=0.5)
plt.xlabel("Room type")
plt.ylabel("minimum number of night stayed")
plt.title("traffic Areas")
plt.show()

# %%
x=traffic_areas2['neighbourhood_group']
y=traffic_areas2['minimum_nights']

plt.bar(x,y,color='blue',width=0.5)
plt.xlabel("neighbourhood_group")
plt.ylabel("minimum number of night stayed")
plt.title("traffic Areas")
plt.show()

# %% [markdown]
# **OBSERVATION:** As we can see the most traffic area which is in room_type is entire home/apt,follwed by private room and we can also say that shared room is less preffered and in
# neighbourhood_group mostly  preffered location is manhattan, Brooklyn, followed by queens.
# reason for this is minimum_nights stayed which are present above.

# %%
best_room = data1.groupby(['room_type'])['number_of_reviews'].count().reset_index()
best_room = best_room.sort_values(by='number_of_reviews', ascending=False)
best_room
# Out:
#          room_type  number_of_reviews
# 0  Entire home/apt              25409
# 1     Private room              22326
# 2      Shared room               1160

# %%
maximum_roombook= data1.groupby(['host_name','room_type'])['minimum_nights'].max().reset_index()
maximum_roombook= maximum_roombook.sort_values(by='minimum_nights', ascending=False)
maximum_roombook
# Out:
#          host_name        room_type  minimum_nights
# 4625     Genevieve  Entire home/apt            1250
# 10617        Peter  Entire home/apt            1000
# 9023           Meg      Shared room             999
# 4834      Glenn H.  Entire home/apt             999
# 883          Angie     Private room             999
# ...            ...              ...             ...
# 11678       Salman      Shared room               1
# 5655        Itziar     Private room               1
# 5645           Ita     Private room               1
# 11687  Sam & Emily  Entire home/apt               1
# 0           #NAME?  Entire home/apt               1
#
# [14591 rows x 3 columns]

# %%
data1.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
price_pred=data1.groupby(['neighbourhood_group'])['price'].mean().reset_index()
price_pred=price_av.sort_values('price', axis=0, ascending=False)
price_pred.head(20)
# Out:
#   neighbourhood_group       price
# 2           Manhattan  196.875814
# 1            Brooklyn  124.383207
# 4       Staten Island  114.812332
# 3              Queens   99.517649
# 0               Bronx   87.496792

# %%
x=price_pred['neighbourhood_group']
y=price_pred['price']

plt.bar(x,y,color='blue',width=0.5)
plt.xlabel("neighbourhood_group")
plt.ylabel("price")
plt.title("price vs neighbourhood_group ")
plt.show()

# %% [markdown]
# **Observation:**
#
# As we can see people are willing to give manhattan as their price is also high.

# %%
plt.figure(figsize=(13,7))
plt.title("Room Type on Neighbourhood Group")
sns.countplot(data1.neighbourhood_group,hue=data1.room_type, palette="muted")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **observation:**
# As we can see Private Entire Home/apt and private room is mostly preffered by people.
